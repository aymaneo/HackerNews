# %% [markdown]
# # Explore Hacker News Data - Delta Lake
#
# **IMT Atlantique - Data Large Scale Project**
#
# This notebook shows how to query Bronze and Silver Delta Lake tables.

# %% [markdown]
# ## 1. Setup Spark with Delta Lake

# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip
from delta.tables import DeltaTable

# Create Spark session with Delta Lake
builder = SparkSession.builder \
    .appName("Explore HN Data") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()
spark.sparkContext.setLogLevel("ERROR")

print("✓ Spark session created with Delta Lake support")

# %% [markdown]
# ## 2. Load Bronze Data (Raw from Kafka)

# %%
# Load Bronze stories
bronze_stories = spark.read.format("delta").load("data/bronze/stories")
print(f"Bronze Stories: {bronze_stories.count()} records")
bronze_stories.show(5, truncate=False)
# Out:
# Bronze Stories: 29 records
# +--------+----------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+-----------------------------------------------------------------------------+-----+---------------------------------------------------------------------+----+-------------+----------------+--------------------------+
# |id      |by        |descendants|kids                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |score|time      |title                                                                        |type |url                                                                  |text|_kafka_offset|_kafka_partition|_bronze_ingested_at       |
# +--------+----------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+-----------------------------------------------------------------------------+-----+---------------------------------------------------------------------+----+-------------+----------------+--------------------------+
# |46585160|grncdr    |18         |[46633139, 46633049, 46633125, 46633113, 46633092, 46632843, 46633073, 46633118, 46632908, 46632889, 46633067, 46632942, 46632990]                                                                                                                                                                                                                                                                                                                                                    |38   |1768202340|Ideas are cheap, execution is cheaper                                        |story|https://davekiss.com/blog/ideas-are-cheap-execution-is-cheaper/      |NULL|0            |0               |2026-01-15 16:11:10.040107|
# |46627652|dreadsword|108        |[46628273, 46631429, 46627778, 46631783, 46628166, 46629741, 46628119, 46627891, 46628725, 46630920, 46628302, 46628785, 46630037, 46632290, 46627888, 46630126, 46630006, 46630368, 46627653, 46629030, 46630698, 46629054, 46629055, 46630788, 46631667, 46629057, 46631631, 46629037, 46627942, 46629852, 46628011, 46630065, 46627726, 46628506, 46627824, 46630165, 46627846, 46631987, 46632199, 46629931, 46629205, 46628232]                                                  |539  |1768447700|The URL shortener that makes your links look as suspicious as possible       |story|https://creepylink.com/                                              |NULL|1            |0               |2026-01-15 16:11:10.040107|
# |46622328|takira    |330        |[46623281, 46623477, 46625422, 46629228, 46627348, 46632110, 46631668, 46625747, 46631485, 46627472, 46630505, 46629342, 46629184, 46631570, 46629821, 46623033, 46623991, 46623995, 46627484, 46632616, 46623265, 46629119, 46623651, 46625799, 46624263, 46627115, 46623550, 46624685, 46623163, 46626296, 46623403, 46628940, 46626187, 46625260, 46624848, 46624221, 46622465, 46623985, 46625592, 46626680, 46623636, 46623514, 46623149, 46627258, 46627251, 46623264, 46628930]|748  |1768421545|Claude Cowork exfiltrates files                                              |story|https://www.promptarmor.com/resources/claude-cowork-exfiltrates-files|NULL|2            |0               |2026-01-15 16:11:10.040107|
# |46553556|speckx    |24         |[46632890, 46632903, 46631562, 46631692, 46632506, 46631740, 46632635, 46631558]                                                                                                                                                                                                                                                                                                                                                                                                      |38   |1767965024|Test your square brackets                                                    |story|https://fluca1978.github.io/2025/12/10/testAndSquareBrackets.html    |NULL|3            |0               |2026-01-15 16:11:10.040107|
# |46630798|suioir    |11         |[46632265, 46632816, 46632791, 46632579, 46632404, 46631634, 46631112]                                                                                                                                                                                                                                                                                                                                                                                                                |34   |1768474748|The 3D Software Rendering Technology of 1998's Thief: The Dark Project (2019)|story|https://nothings.org/gamedev/thief_rendering.html                    |NULL|4            |0               |2026-01-15 16:11:10.040107|
# +--------+----------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+-----------------------------------------------------------------------------+-----+---------------------------------------------------------------------+----+-------------+----------------+--------------------------+
# only showing top 5 rows

# %%
# Load Bronze comments
bronze_comments = spark.read.format("delta").load("data/bronze/comments")
print(f"Bronze Comments: {bronze_comments.count()} records")
bronze_comments.show(5, truncate=False)
# Out:
# Bronze Comments: 577 records
# +--------+----------+--------------------+--------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------+-------+----+-------------+----------------+-------------------------+
# |id      |by        |kids                |parent  |story_id|text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |time      |type   |deleted|dead|_kafka_offset|_kafka_partition|_bronze_ingested_at      |
# +--------+----------+--------------------+--------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------+-------+----+-------------+----------------+-------------------------+
# |46633139|mikert89  |NULL                |46585160|46585160|when software gets cheap to build, a lot of weird things happen. It&#x27;s not just that the product is easier to build; it means that sales, marketing, and other business units can iterate faster to produce a better product.<p>The result is that there is no moat, and I think we&#x27;re going to see an absolute blood bath in SAAS as this becomes more and more obvious. People still say, &quot;Oh, well, distribution is now the hard part,&quot; but if the product is trivial to build, it used to be the case that sales was hard because you had to build and refine the sales motion on a product that didn&#x27;t evolve quickly.<p>There was a lot of risk in the product, and then you had to figure out the distribution before the product was set. So you didn&#x27;t waste a lot of resources building and finding that distribution didn&#x27;t work. All these equations and all these variables we previously held true about SAAS will no longer hold true|1768487992|comment|NULL   |NULL|0            |0               |2026-01-15 16:11:14.34116|
# |46633049|sgt       |[46633088, 46633071]|46585160|46585160|&gt; I&#x27;m not joking and this isn&#x27;t funny. We have been trying to build distributed agent orchestrators at Google since last year. There are various options, not everyone is aligned... I gave Claude Code a description of the problem, it generated what we built last year in an hour.<p>I am sure that whatever work was put into actually trying to implement that, was crucial in order to instruct Claude what to do. System design doesn&#x27;t come by itself.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |1768487560|comment|NULL   |NULL|1            |0               |2026-01-15 16:11:14.34116|
# |46633125|AstroBen  |NULL                |46585160|46585160|[delayed]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |1768487926|comment|NULL   |NULL|2            |0               |2026-01-15 16:11:14.34116|
# |46633113|josh2600  |NULL                |46585160|46585160|LLMs are amazing.<p>Nothing replaces making simple UX instead of complicated kitchen sink products.<p>It’s easy to make stuff. It’s harder to make stuff people want.<p>I am thankful for the increase in product velocity and I also recognize that a lot of stuff people make isn’t what people want.<p>Product sense and intuition still matter.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |1768487862|comment|NULL   |NULL|3            |0               |2026-01-15 16:11:14.34116|
# |46633092|Bishonen88|NULL                |46585160|46585160|That&#x27;s what I was thinking as well after letting Claude do a godoist clone in a few vibe coding sessions. Literally got most features I care about with a ui similar to todoist with all the bootstraping done. Deploying to my nas later this week and cancelling my subscription.<p>It&#x27;s way past the point of &quot;just&quot; doing MVPs or simple proof of concepts. I&#x27;m talking about user auth, dynamic input parsing, calendar views, tags, projects, history of events and more, given a few prompts.                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1768487744|comment|NULL   |NULL|4            |0               |2026-01-15 16:11:14.34116|
# +--------+----------+--------------------+--------+--------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------+-------+----+-------------+----------------+-------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 3. Load Silver Data (Cleaned)

# %%
# Load Silver stories
silver_stories = spark.read.format("delta").load("data/silver/stories")
print(f"Silver Stories: {silver_stories.count()} records")
silver_stories.show(5, truncate=False)
# Out:
# Silver Stories: 29 records
# +--------+------------+-----------------------------------------------+-----------------------------------------------------------------+-----+-------------+--------+----------+-------------------+-------+--------+-----+--------------------------+
# |id      |author      |title                                          |url                                                              |score|comment_count|text_raw|text_clean|timestamp          |has_url|has_text|type |_bronze_ingested_at       |
# +--------+------------+-----------------------------------------------+-----------------------------------------------------------------+-----+-------------+--------+----------+-------------------+-------+--------+-----+--------------------------+
# |46553556|speckx      |Test your square brackets                      |https://fluca1978.github.io/2025/12/10/testAndSquareBrackets.html|38   |24           |        |          |2026-01-09 14:23:44|true   |false   |story|2026-01-15 16:11:10.040107|
# |46558224|surprisetalk|San Remo Pasta Measurer                        |https://www.toxel.com/tech/2025/09/17/san-remo-pasta-measurer/   |28   |17           |        |          |2026-01-09 20:39:53|true   |false   |story|2026-01-15 16:11:10.040107|
# |46564866|todsacerdoti|Bare metal programming with RISC-V guide (2023)|https://popovicu.com/posts/bare-metal-programming-risc-v/        |47   |8            |        |          |2026-01-10 12:38:39|true   |false   |story|2026-01-15 16:11:10.040107|
# |46584523|exvi        |Z80 Mem­ber­ship Card                          |https://sunrise-ev.com/z80.htm                                   |52   |16           |        |          |2026-01-12 06:42:09|true   |false   |story|2026-01-15 16:11:10.040107|
# |46585160|grncdr      |Ideas are cheap, execution is cheaper          |https://davekiss.com/blog/ideas-are-cheap-execution-is-cheaper/  |38   |18           |        |          |2026-01-12 08:19:00|true   |false   |story|2026-01-15 16:11:10.040107|
# +--------+------------+-----------------------------------------------+-----------------------------------------------------------------+-----+-------------+--------+----------+-------------------+-------+--------+-----+--------------------------+
# only showing top 5 rows

# %%
# Load Silver comments
silver_comments = spark.read.format("delta").load("data/silver/comments")
print(f"Silver Comments: {silver_comments.count()} records")
silver_comments.show(5, truncate=False)
# Out:
# Silver Comments: 576 records
# +--------+-------------+--------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+--------+----------+----------+-----------+----------+-------+-------------+-------+-------------------------+
# |id      |author       |story_id|parent  |text_raw                                                                                                                                                                                                                     |text_clean                                                                                                                                               |timestamp          |has_text|word_count|char_count|has_replies|is_deleted|is_dead|quality_score|type   |_bronze_ingested_at      |
# +--------+-------------+--------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+--------+----------+----------+-----------+----------+-------+-------------+-------+-------------------------+
# |46565017|sylware      |46564866|46564866|Everything RISC-V is kewl.                                                                                                                                                                                                   |Everything RISC-V is kewl.                                                                                                                               |2026-01-10 13:03:11|true    |4         |26        |false      |false     |false  |0.5          |comment|2026-01-15 16:11:14.34116|
# |46617581|eajr         |46616529|46616529|Local LibreChat which bundles a vector db for docs.                                                                                                                                                                          |Local LibreChat which bundles a vector db for docs.                                                                                                      |2026-01-14 16:57:07|true    |9         |51        |false      |false     |false  |1.0          |comment|2026-01-15 16:11:14.34116|
# |46618134|rahimnathwani|46616529|46616529|If your data aren&#x27;t too large, you can use faiss-cpu and pickle<p><a href="https:&#x2F;&#x2F;pypi.org&#x2F;project&#x2F;faiss-cpu&#x2F;" rel="nofollow">https:&#x2F;&#x2F;pypi.org&#x2F;project&#x2F;faiss-cpu&#x2F;</a>|If your data aren't too large, you can use faiss-cpu and pickle\n\nhttps://pypi.org/project/faiss-cpu/                                                   |2026-01-14 17:31:29|true    |13        |100       |true       |false     |false  |1.0          |comment|2026-01-15 16:11:14.34116|
# |46618327|motakuk      |46616529|46616529|LightRAG, Archestra as a UI with LightRAG mcp                                                                                                                                                                                |LightRAG, Archestra as a UI with LightRAG mcp                                                                                                            |2026-01-14 17:42:48|true    |8         |45        |false      |false     |false  |1.0          |comment|2026-01-15 16:11:14.34116|
# |46619558|blahaj       |46619464|46619464|I found out today that the location header of an HTTP redirect can be a tel:+ URI and phone&#x27;s will actually ask you whether you want to call that number.                                                               |I found out today that the location header of an HTTP redirect can be a tel:+ URI and phone's will actually ask you whether you want to call that number.|2026-01-14 18:58:47|true    |30        |153       |true       |false     |false  |1.0          |comment|2026-01-15 16:11:14.34116|
# +--------+-------------+--------+--------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+--------+----------+----------+-----------+----------+-------+-------------+-------+-------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 4. View Schema

# %%
print("=== Silver Stories Schema ===")
silver_stories.printSchema()
# Out:
# === Silver Stories Schema ===
# root
#  |-- id: integer (nullable = true)
#  |-- author: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- score: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- text_raw: string (nullable = true)
#  |-- text_clean: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- has_url: boolean (nullable = true)
#  |-- has_text: boolean (nullable = true)
#  |-- type: string (nullable = true)
#  |-- _bronze_ingested_at: timestamp (nullable = true)

# %%
print("=== Silver Comments Schema ===")
silver_comments.printSchema()
# Out:
# === Silver Comments Schema ===
# root
#  |-- id: integer (nullable = true)
#  |-- author: string (nullable = true)
#  |-- story_id: integer (nullable = true)
#  |-- parent: integer (nullable = true)
#  |-- text_raw: string (nullable = true)
#  |-- text_clean: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- has_text: boolean (nullable = true)
#  |-- word_count: integer (nullable = true)
#  |-- char_count: integer (nullable = true)
#  |-- has_replies: boolean (nullable = true)
#  |-- is_deleted: boolean (nullable = true)
#  |-- is_dead: boolean (nullable = true)
#  |-- quality_score: double (nullable = true)
#  |-- type: string (nullable = true)
#  |-- _bronze_ingested_at: timestamp (nullable = true)

# %% [markdown]
# ## 5. Statistics

# %%
# Story statistics
print("=== Story Statistics ===")
silver_stories.select("score", "comment_count").describe().show()
# Out:
# === Story Statistics ===
# +-------+------------------+------------------+
# |summary|             score|     comment_count|
# +-------+------------------+------------------+
# |  count|                29|                29|
# |   mean|159.27586206896552| 136.6206896551724|
# | stddev|192.79372703038345|354.89992692036276|
# |    min|                 5|                 0|
# |    max|               748|              1936|
# +-------+------------------+------------------+

# %%
# Comment statistics
print("=== Comment Statistics ===")
silver_comments.select("word_count", "quality_score").describe().show()
# Out:
# === Comment Statistics ===
# +-------+-----------------+-------------------+
# |summary|       word_count|      quality_score|
# +-------+-----------------+-------------------+
# |  count|              576|                576|
# |   mean|50.60069444444444| 0.9381944444444446|
# | stddev|54.65070363876903|0.18593931792843288|
# |    min|                1|                0.2|
# |    max|              383|                1.0|
# +-------+-----------------+-------------------+

# %% [markdown]
# ## 6. Example Queries

# %%
# Top 10 stories by score
print("=== Top 10 Stories by Score ===")
silver_stories.orderBy("score", ascending=False) \
    .select("title", "score", "comment_count", "author") \
    .show(10, truncate=False)
# Out:
# === Top 10 Stories by Score ===
# +------------------------------------------------------------------------+-----+-------------+--------------+
# |title                                                                   |score|comment_count|author        |
# +------------------------------------------------------------------------+-----+-------------+--------------+
# |Claude Cowork exfiltrates files                                         |748  |330          |takira        |
# |Ask HN: Share your personal website                                     |703  |1936         |susam         |
# |The URL shortener that makes your links look as suspicious as possible  |539  |108          |dreadsword    |
# |A letter to those who fired tech writers because of AI                  |246  |162          |theletterf    |
# |Ask HN: How are you doing RAG locally?                                  |242  |100          |tmaly         |
# |Scaling long-running autonomous coding                                  |231  |142          |samwillis     |
# |Photos Capture the Breathtaking Scale of China's Wind and Solar Buildout|229  |165          |mrtksn        |
# |Furiosa: 3.5x efficiency over H100s                                     |190  |130          |written-beyond|
# |The State of OpenSSL for pyca/cryptography                              |170  |38           |SGran         |
# |Raspberry Pi's New AI Hat Adds 8GB of RAM for Local LLMs                |167  |124          |ingve         |
# +------------------------------------------------------------------------+-----+-------------+--------------+
# only showing top 10 rows

# %%
# Top 10 most active authors (by comment count)
print("=== Top 10 Most Active Authors ===")
from pyspark.sql.functions import count

silver_comments.groupBy("author") \
    .agg(count("*").alias("comment_count")) \
    .orderBy("comment_count", ascending=False) \
    .show(10)
# Out:
# === Top 10 Most Active Authors ===
# +--------------+-------------+
# |        author|comment_count|
# +--------------+-------------+
# |          NULL|           12|
# |         Havoc|            5|
# |   Barathkanna|            4|
# |    reactordev|            4|
# |      torginus|            3|
# |    prakashn27|            2|
# |        Nora23|            2|
# |       nottorp|            2|
# |        simonw|            2|
# |dfajgljsldkjag|            2|
# +--------------+-------------+
# only showing top 10 rows

# %%
# High quality comments (score > 0.9)
print("=== High Quality Comments ===")
silver_comments.filter("quality_score > 0.9") \
    .select("author", "word_count", "quality_score", "text_clean") \
    .show(5, truncate=80)
# Out:
# === High Quality Comments ===
# +-------------+----------+-------------+--------------------------------------------------------------------------------+
# |       author|word_count|quality_score|                                                                      text_clean|
# +-------------+----------+-------------+--------------------------------------------------------------------------------+
# |         eajr|         9|          1.0|                             Local LibreChat which bundles a vector db for docs.|
# |rahimnathwani|        13|          1.0|If your data aren't too large, you can use faiss-cpu and pickle\n\nhttps://py...|
# |      motakuk|         8|          1.0|                                   LightRAG, Archestra as a UI with LightRAG mcp|
# |       blahaj|        30|          1.0|I found out today that the location header of an HTTP redirect can be a tel:+...|
# |  simonsarris|        51|          1.0|https://simonsarris.com - My site\n\nhttps://map.simonsarris.com - My newslet...|
# +-------------+----------+-------------+--------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Join stories with their comments
print("=== Stories with Comment Stats ===")
from pyspark.sql.functions import avg, count

comment_stats = silver_comments.groupBy("story_id") \
    .agg(
        count("*").alias("actual_comments"),
        avg("word_count").alias("avg_word_count"),
        avg("quality_score").alias("avg_quality")
    )

stories_with_stats = silver_stories.join(
    comment_stats,
    silver_stories.id == comment_stats.story_id,
    "left"
).select(
    silver_stories.title,
    silver_stories.score,
    comment_stats.actual_comments,
    comment_stats.avg_word_count,
    comment_stats.avg_quality
)

stories_with_stats.show(10, truncate=False)
# Out:
# === Stories with Comment Stats ===
# +-------------------------------------------------------------------------------+-----+---------------+------------------+------------------+
# |title                                                                          |score|actual_comments|avg_word_count    |avg_quality       |
# +-------------------------------------------------------------------------------+-----+---------------+------------------+------------------+
# |Test your square brackets                                                      |38   |8              |49.125            |1.0               |
# |San Remo Pasta Measurer                                                        |28   |8              |28.0              |1.0               |
# |Bare metal programming with RISC-V guide (2023)                                |47   |3              |60.333333333333336|0.8333333333333334|
# |Z80 Mem­ber­ship Card                                                          |52   |9              |50.22222222222222 |1.0               |
# |Ideas are cheap, execution is cheaper                                          |38   |13             |67.92307692307692 |0.8999999999999999|
# |Impeccable Style                                                               |31   |10             |27.9              |0.79              |
# |Ask HN: How are you doing RAG locally?                                         |242  |50             |53.62             |0.9440000000000001|
# |Ask HN: Share your personal website                                            |703  |50             |22.94             |0.8440000000000001|
# |Ask HN: What did you find out or explore today?                                |139  |50             |81.38             |1.0               |
# |Show HN: Sparrow-1 – Audio-native model for human-level turn-taking without ASR|88   |11             |38.63636363636363 |0.9545454545454546|
# +-------------------------------------------------------------------------------+-----+---------------+------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## 7. Delta Lake Time Travel

# %%
# View transaction history
print("=== Delta Lake Transaction History ===")
dt = DeltaTable.forPath(spark, "data/bronze/stories")
dt.history().select("version", "timestamp", "operation", "operationMetrics").show(truncate=False)
# Out:
# === Delta Lake Transaction History ===
# +-------+-----------------------+---------+-------------------------------------------------------------+
# |version|timestamp              |operation|operationMetrics                                             |
# +-------+-----------------------+---------+-------------------------------------------------------------+
# |0      |2026-01-15 16:11:11.379|WRITE    |{numFiles -> 1, numOutputRows -> 29, numOutputBytes -> 21666}|
# +-------+-----------------------+---------+-------------------------------------------------------------+

# %%
# Query previous version (if exists)
print("=== Query Version 0 ===")
df_v0 = spark.read.format("delta").option("versionAsOf", 0).load("data/bronze/stories")
print(f"Version 0 had {df_v0.count()} records")

# %% [markdown]
# ## 8. SQL Queries (Alternative)

# %%
# Register as SQL tables
silver_stories.createOrReplaceTempView("stories")
silver_comments.createOrReplaceTempView("comments")

print("✓ Registered SQL tables: stories, comments")

# %%
# SQL query example
spark.sql("""
    SELECT 
        s.title,
        s.score,
        COUNT(c.id) as comment_count,
        AVG(c.quality_score) as avg_quality
    FROM stories s
    LEFT JOIN comments c ON s.id = c.story_id
    GROUP BY s.title, s.score
    ORDER BY s.score DESC
    LIMIT 10
""").show(truncate=False)

# %% [markdown]
# ## 9. Convert to Pandas (for visualization)

# %%
# Convert to Pandas for plotting
stories_pd = silver_stories.toPandas()
comments_pd = silver_comments.toPandas()

print(f"Stories: {len(stories_pd)} rows")
print(f"Comments: {len(comments_pd)} rows")

# Preview
stories_pd.head()

# %%
# Example visualization with seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(comments_pd['quality_score'], bins=20, kde=True)
plt.title('Distribution of Comment Quality Scores')
plt.xlabel('Quality Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       3 import matplotlib.pyplot as plt
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.histplot(comments_pd['quality_score'], bins=20, kde=True)
#       7 plt.title('Distribution of Comment Quality Scores')
#       8 plt.xlabel('Quality Score')
#
# NameError: name 'comments_pd' is not defined

# %% [markdown]
# ## 10. Cleanup

# %%
# Stop Spark session when done
spark.stop()
print("✓ Spark session stopped")
